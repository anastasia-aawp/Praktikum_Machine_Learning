# %%
# Impor library
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Mengimpor modul files dari pustaka google.colab
from google.colab import files
# Menggunakan modul files untuk meng-upload file ke sesi Google Colab
upload = files.upload()
# Out:
#      <input type="file" id="files-8d63b5de-3324-4e3f-9759-b82cc2531d17" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d63b5de-3324-4e3f-9759-b82cc2531d17">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv('CAD.csv')

# %%
# Memilih fitur dan label
features = dataset[['Age', 'Weight', 'Height', 'BMI', 'DM', 'HTN', 'Current Smoker', 'Obesity', 'DLP', 'BP',
                    'WPE', 'Typical Chest Pain', 'Atypical', 'Nonanginal', 'St Depression', 'Tinversion', 'LVH',
                    'PRP', 'FBS', 'ESR', 'EF', 'RWMA', 'EX-Smoker', 'CR', 'BUN']]
labels = dataset['CAD']

# %%
dataset.drop('Sex', axis=1, inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 303 non-null    int64
#  1   Weight              303 non-null    int64
#  2   Height              303 non-null    int64
#  3   BMI                 303 non-null    float64
#  4   DM                  303 non-null    int64
#  5   HTN                 303 non-null    int64
#  6   Current Smoker      303 non-null    int64
#  7   Obesity             303 non-null    object
#  8   DLP                 303 non-null    object
#  9   BP                  303 non-null    int64
#  10  WPE                 303 non-null    object
#  11  Typical Chest Pain  303 non-null    int64
#  12  Atypical            303 non-null    object
#  13  Nonanginal          303 non-null    object
#  14  St Depression       303 non-null    int64
#  15  Tinversion          303 non-null    int64
# ...

# %%
# Mengecek apakah ada nilai non-numerik di dalam fitur
non_numeric_columns = features.select_dtypes(exclude=['number']).columns
if not non_numeric_columns.empty:
    print(f"Kolom dengan nilai non-numerik di fitur: {non_numeric_columns}")
    print("Konversi nilai non-numerik ke bentuk numerik diperlukan.")
    exit()
# Out:
# Kolom dengan nilai non-numerik di fitur: Index(['Obesity', 'DLP', 'WPE', 'Atypical', 'Nonanginal', 'LVH', 'PRP'], dtype='object')
# Konversi nilai non-numerik ke bentuk numerik diperlukan.

# %%
from sklearn.model_selection import train_test_split
# Membagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Normalisasi fitur menggunakan StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2dc01970841a> in <cell line: 3>()
#       1 from sklearn.model_selection import train_test_split
#       2 # Membagi data menjadi data latih dan data uji
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
#       4
#       5 # Normalisasi fitur menggunakan StandardScaler
#
# NameError: name 'features' is not defined

# %%
# Membuat model KNN
knn_model = KNeighborsClassifier(n_neighbors=3)  # Ubah nilai n_neighbors sesuai kebutuhan

# Melatih model
knn_model.fit(X_train_scaled, y_train)

# Melakukan prediksi pada data uji
y_pred = knn_model.predict(X_test_scaled)

# Evaluasi model
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred)

# Menampilkan hasil
print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:\n', classification_report_result)

# %%
print(X_train_scaled.shape)
print(X_train.shape)
